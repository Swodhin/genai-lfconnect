# %% [markdown]
# <a href="https://colab.research.google.com/github/Swodhin/genai-lfconnect/blob/main/week-1/class-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class 1 — Python Syntax, Control Flow & Data Structures
# **Week 1: Python Foundations for Generative AI — "The Interpreter"**
#
# ### Learning objectives
# By the end of this notebook you will be able to:
# - Create variables and reason about Python's dynamic typing
# - Use the five core data types: `int`, `float`, `str`, `bool`, `None`
# - Branch logic with `if` / `elif` / `else`
# - Repeat work with `for` and `while` loops
# - Choose the right data structure among `list`, `tuple`, `dict`, and `set`
#
# Run each cell in order with **Shift+Enter**. There are no API keys needed for this notebook — it's pure Python.

# %% [markdown]
# ## Setup
# No external packages are required for this class. We just confirm the Python version and get started.

# %%
import sys
print(f"Python version: {sys.version.split()[0]}")
print("Setup complete — no API keys needed for this notebook.")
# Out:
# Python version: 3.12.13
# Setup complete — no API keys needed for this notebook.

# %% [markdown]
# ## 1. Variables & Dynamic Typing
# A variable is a name bound to a value. Python figures out the type at runtime — you never declare it up front. This is called **dynamic typing**.

# %%
model_name = "gpt-4"
temperature = 0.7
is_ready = True

print(model_name, type(model_name))
print(temperature, type(temperature))
print(is_ready, type(is_ready))

# Legal, but a readability smell: reassigning a name to a different type
temperature = "warming up"
print(temperature, type(temperature))

# %% [markdown]
# ## 2. Core Data Types
# The five types you'll reach for constantly: `int`, `float`, `str`, `bool`, and `None` (Python's "nothing here yet" value).

# %%
token_count = 128          # int
avg_latency_sec = 1.42     # float
prompt = "Summarize this." # str
has_error = False          # bool
cached_response = None     # NoneType

for value in [token_count, avg_latency_sec, prompt, has_error, cached_response]:
    print(f"{value!r:30} -> {type(value)}")

# %% [markdown]
# ## 3. Conditionals — if / elif / else
# Indentation (4 spaces) defines a block in Python — there are no curly braces. `elif` checks another condition if the first was `False`; `else` catches everything remaining.

# %%
score = 82

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
else:
    grade = "C"

print(f"Score {score} -> grade {grade}")

# %% [markdown]
# ## 4. for Loops
# `for` walks through any iterable: a string, a list, `range()`, a dict, and more. `enumerate()` hands you `(index, value)` pairs for free.

# %%
prompts = ["Hi", "Explain RAG", "Bye"]

for i, prompt in enumerate(prompts):
    print(f"{i}: {prompt}")

# %% [markdown]
# ## 5. while Loops
# `while` repeats as long as its condition stays `True` — useful when you don't know the number of iterations in advance (like polling an API until a job finishes).

# %%
attempts = 0

while attempts < 3:
    print(f"Attempt {attempts + 1}")
    attempts += 1

print("Done")

# %% [markdown]
# ## 6. Lists & Tuples
# Both are ordered and support indexing/slicing. Lists (`[]`) are **mutable** — they can grow, shrink, and change. Tuples (`()`) are **immutable** — once created, they can't be changed, which makes them a good fit for fixed groupings like coordinates.

# %%
history = ["hi"]
history.append("how are you?")
print(history)

point = (10, 20)
print(point[0], point[1])

try:
    point[0] = 99
except TypeError as e:
    print(f"Can't do that: {e}")

# %% [markdown]
# ## 7. Dicts & Sets
# A `dict` maps keys to values — perfect for JSON-like configuration. A `set` holds only unique, unordered items — perfect for de-duplication and fast membership tests.

# %%
config = {"model": "gpt-4", "temperature": 0.7}
print(config["model"])
config["max_tokens"] = 500
print(config)

seen = {"a", "b", "a"}
print(seen)
print("a" in seen)

# %% [markdown]
# ## 8. Demo: Building a Tiny Word Counter
# One `dict` plus one `for` loop is enough to build a small analytics tool. This exact pattern shows up again later when you tally tokens or count API responses by type.

# %%
text = "the cat sat on the mat the cat ran"
counts = {}

for word in text.split():
    counts[word] = counts.get(word, 0) + 1

for word, n in sorted(counts.items()):
    print(f"{word}: {n}")

# %% [markdown]
# ## Fun fact — `import antigravity`
# Try running `import this` in any Python shell — it prints the *Zen of Python*, 19 lines of design philosophy, including: *"There should be one — and preferably only one — obvious way to do it."* That's exactly why Python favors one clean `for` loop over five clever ways to do the same thing: readable code is the point, not clever code. (`import antigravity` is a real easter egg too — it opens a webcomic in your browser. Python has a sense of humor about its own philosophy.)

# %%
import this

# %% [markdown]
# ## Challenges
# Work through these in order. No solutions are provided — that's the point. Each starter cell has a `# TODO` marking where your code goes.

# %% [markdown]
# ### Challenge 1 — FizzBuzz with a Twist
# Write a loop over the numbers 1 through 30. For multiples of 3 print `"Fizz"`, for multiples of 5 print `"Buzz"`, for multiples of both print `"FizzBuzz"`, otherwise print the number. **Twist:** also print `"Bang"` for multiples of 7 (so a multiple of 3, 5, and 7 prints `"FizzBuzzBang"`).
#
# **Acceptance criteria:** running the cell prints exactly 30 lines, one per number, with the correct word(s).

# %%
# TODO: implement FizzBuzz with a Twist
for number in range(1, 31):
    result = ""

    if number % 3 == 0:
        result += "Fizz"

    if number % 5 == 0:
        result += "Buzz"

    if number % 7 == 0:
        result += "Bang"

    if result:
        print(result)
    else:
        print(number)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# Bang
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# Bang
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# FizzBang
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# Bang
# 29
# FizzBuzz

# %% [markdown]
# ### Challenge 2 — Grade Calculator
# Write a function `grade_for(score)` that takes an integer 0-100 and returns `"A"` (90+), `"B"` (80-89), `"C"` (70-79), `"D"` (60-69), or `"F"` (below 60). Test it on at least 5 different scores.
#
# **Acceptance criteria:** `grade_for(95) == "A"`, `grade_for(50) == "F"`, and 3 more test calls all print correct results.

# %%
# TODO: write grade_for(score) and test it
def grade_for(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"


print(grade_for(95))
print(grade_for(85))
print(grade_for(75))
print(grade_for(65))
print(grade_for(50))
# Out:
# A
# B
# C
# D
# F

# %% [markdown]
# ### Challenge 3 — De-duplicate a Guest List
# Given the list below, use a `set` to produce a list of unique guest names, then print how many duplicates were removed.
#
# ```python
# guests = ["Ada", "Grace", "Ada", "Alan", "Grace", "Linus"]
# ```
# **Acceptance criteria:** prints the unique guest list and the count of duplicates removed (should be 2).

# %%
guests = ["Ada", "Grace", "Ada", "Alan", "Grace", "Linus"]
# TODO: de-duplicate `guests` using a set and report how many duplicates were removed
unique_guests = list(set(guests))
duplicates_removed = len(guests) - len(unique_guests)

print("Unique guests:", unique_guests)
print("Duplicates removed:", duplicates_removed)
# Out:
# Unique guests: ['Alan', 'Grace', 'Linus', 'Ada']
# Duplicates removed: 2

# %% [markdown]
# ### Challenge 4 — Invert a Dictionary
# Given `model_ids = {"gpt-4": 1, "claude": 2, "llama": 3}`, write code that builds a new dict mapping id -> model name (the reverse of the original).
#
# **Acceptance criteria:** the new dict equals `{1: "gpt-4", 2: "claude", 3: "llama"}`.

# %%
model_ids = {"gpt-4": 1, "claude": 2, "llama": 3}
# TODO: build the inverted dictionary

inverted_model_ids = {
    model_id: model_name
    for model_name, model_id in model_ids.items()
}

print(inverted_model_ids)
# Out:
# {1: 'gpt-4', 2: 'claude', 3: 'llama'}

# %% [markdown]
# ### Challenge 5 (Stretch) — Word Frequency Counter
# Pick any paragraph of text (write your own 3-4 sentences as a string). Count how many times each word appears, ignoring case, and print the top 5 most frequent words with their counts.
#
# **Acceptance criteria:** works on any paragraph you provide, is case-insensitive, and prints exactly the 5 most frequent words (fewer if the paragraph is short).

# %%
# TODO: count word frequency (case-insensitive) and print the top 5 words
paragraph = """
Python is easy to learn. Python is also powerful.
Many developers use Python because Python is readable.
Readable code is easier to maintain.
"""

word_counts = {}

for word in paragraph.lower().split():
    word = word.strip(".,!?;:\"'()")

    if word:
        word_counts[word] = word_counts.get(word, 0) + 1

top_five = sorted(
    word_counts.items(),
    key=lambda item: item[1],
    reverse=True
)[:5]

for word, count in top_five:
    print(f"{word}: {count}")
# Out:
# python: 4
# is: 4
# to: 2
# readable: 2
# easy: 1
